# %% [markdown]
# # Final Project Meteo 473 Milestone 1

# %% [markdown]
# # Hazard Selection & Index Planning

# %% [markdown]
# Hazard or application area is clearly identified in a
# markdown cell

# %% [markdown]
# | Problem | What we are attempting to track   |
# |-------------------|------|
# |   Severe Weather  | Weather incident in Norman, OK October 12th, 2021|

# %% [markdown]
# Preliminary ideas are thoughtful and well-articulated
# (e.g., who might use the index, why it's important)

# %% [markdown]
# Early brainstorming shows a plan for index output and
# how variables might be combined or weighted

# %% [markdown]
# # Collecting Model Data & Observations

# %% [markdown]
# One complete model run downloaded (0–240 hrs),
# saved as a single NetCDF file

# %% [markdown]
# Unnecessary variables excluded; temporary files
# cleaned up

# %% [markdown]
# Two or more ground-truth observation images included
# (e.g., storm reports, analysis maps) and are clearly
# described in notebook

# %% [markdown]
# # Visualizations & Plot Quality

# %% [markdown]
# At least four relevant variables plotted from a selected
# time step
#
# **2 Meter Temperature, Relative Humidity, Total Cloud Cover, Precipitation Rate, Lightning**

# %% [markdown]
# A useful custom colormap was created and used in at
# least one plot

# %% [markdown]
# At least one derived parameter calculated and plotted

# %% [markdown]
# Plots are readable and informative: consistent styling,
# appropriate colormaps, consistent color levels and
# contours, clear titles, clear map backgrounds

# %% [markdown]
# # Documentation & Code Quality

# %% [markdown]
# Code includes clear comments explaining what and
# why things are done

# %% [markdown]
# Markdown is used effectively with proper formatting
# (headings, subheadings, bullet points)

# %% [markdown]
# Extended explanations demonstrate effort and
# thoughtfulness, not just surface-level descriptions

# %% [markdown]
# Notebook is well-organized and readable; group
# members’ contributions are documented

# %% [markdown]
# Code avoids redundancy and runs top-to-bottom
# without error; all output is rendered properly

# %% [markdown]
# Model data is referenced from saved files;
# unnecessary re-downloading is avoided

# %% [markdown]
# # Bonus

# %% [markdown]
# A time–height or distance–height cross-section is
# included with ≥2 variables and appropriate labeling
